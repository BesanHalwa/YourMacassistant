# %%
"""
https://pypi.org/project/SpeechRecognition/
https://github.com/Uberi/speech_recognition/blob/master/reference/library-reference.rst
https://github.com/Uberi/speech_recognition/tree/master/examples
https://www.geeksforgeeks.org/speech-recognition-in-python-using-google-speech-api/
"""

# %%
# !pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
#     100% |████████████████████████████████| 32.8MB 160kB/s ta 0:00:011
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.8.1
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !brew install portaudio
# Out:
# Updating Homebrew...
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# aws-okta                                 luarocks
# badtouch                                 luit
# black                                    micronaut
# bloaty                                   miniserve
# cash-cli                                 pcapplusplus
# cwlogs                                   perltidy
# docker-credential-helper-ecr             petsc-complex
# docker-machine-driver-hyperkit           pijul
# eslint                                   pulumi
# fauna-shell                              range-v3
# gambit                                   safe
# geogram                                  serverless
# go@1.10                                  sfst
# gptfdisk                                 thors-serializer
# gradio                                   topgrade
# helmfile                                 weaver
# infrakit                                 wiremock-standalone
# json11                                   wsk
# kubernetes-service-catalog-client        wskdeploy
# kustomize                                xsimd
# libsignal-protocol-c                     yarn-completion
# lsusb                                    zlog
# ==> Updated Formulae
# automake ✔                               libssh
# fontconfig ✔                             libtensorflow
# gcc ✔                                    libuv
# gdbm ✔                                   libvirt
# hdf5 ✔                                   libwps
# isl ✔                                    libxkbcommon
# numpy ✔                                  lighttpd
# openssl ✔                                link-grammar
# abcde                                    linkerd
# abcm2ps                                  liquigraph
# ace                                      log4cplus
# acpica                                   logtalk
# activemq                                 lolcat
# advancemame                              lrzsz
# alexjs                                   lsof
# angband                                  lua
# angle-grinder                            lua@5.1
# angular-cli                              lxc
# annie                                    lynis
# ansible                                  mackup
# ansible-cmdb                             macvim
# apache-arrow                             mafft
# apache-arrow-glib                        mapcrafter
# apache-flink                             mariadb
# app-engine-python                        mariadb@10.0
# appscale-tools                           mariadb@10.1
# arangodb                                 mariadb@10.2
# argyll-cms                               mbedtls
# ark                                      mdcat
# arm-linux-gnueabihf-binutils             mdds
# armadillo                                mdp
# artifactory                              media-info
# asdf                                     megatools
# ats2-postiats                            memcached
# augeas                                   mercurial
# aws-elasticbeanstalk                     meson
# aws-sdk-cpp                              metabase
# awscli                                   micro
# azure-cli                                mikutter
# b2-tools                                 mill
# babel                                    mingw-w64
# babl                                     minimal-racket
# ballerina                                minizinc
# bartycrouch                              mint
# bat                                      mitmproxy
# bdw-gc                                   mkcert
# bear                                     mkdocs
# beast                                    mkl-dnn
# bench                                    mkvtoolnix
# bettercap                                mlkit
# binaryen                                 modules
# bind                                     monetdb
# bison                                    mongo-cxx-driver
# bitcoin                                  mongodb
# bitrise                                  mongodb@3.6
# bitwarden-cli                            mongoose
# blockhash                                mono
# bowtie2                                  mosquitto
# bro                                      mpd
# buildifier                               mr
# bwfmetaedit                              mrtg
# byobu                                    msgpack
# cabextract                               msitools
# caffe                                    mujs
# cake                                     mysql
# calabash                                 mysql-client
# cargo-completion                         mysql@5.5
# cassandra                                mysql@5.6
# cataclysm                                mysql@5.7
# ccrypt                                   nagios
# ceres-solver                             nativefier
# chakra                                   naturaldocs
# checkstyle                               nco
# chrome-cli                               ncview
# chronograf                               neo4j
# cimg                                     netcdf
# circleci                                 nghttp2
# ckan                                     nginx
# closure-compiler                         nnn
# cmake                                    node
# cmark-gfm                                node-build
# cmocka                                   node@6
# cockroach                                node@8
# commandbox                               nsd
# composer                                 nspr
# conan                                    ntl
# confluent-oss                            ntp
# confuse                                  nuxeo
# consul                                   nyancat
# convox                                   ocaml
# corsixth                                 ocrmypdf
# cquery                                   octave
# creduce                                  open-mpi
# cryptol                                  openapi-generator
# crystal                                  openblas
# csvprintf                                opencoarrays
# cython                                   openimageio
# dartsim                                  openrct2
# dateutils                                openshift-cli
# dbus                                     openssh
# dcos-cli                                 openssl@1.1
# ddclient                                 openvdb
# deark                                    osc
# dep                                      osmium-tool
# dependency-check                         osquery
# deployer                                 p11-kit
# di                                       paket
# diff-pdf                                 pandoc
# discount                                 pango
# distcc                                   parallel
# dita-ot                                  passenger
# django-completion                        pazpar2
# dmd                                      pc6001vx
# docfx                                    pcb2gcode
# docker                                   pcl
# docker-completion                        pdal
# docker-credential-helper                 pdftoedn
# doctl                                    pdftoipe
# draco                                    pegtl
# dropbear                                 percona-server-mongodb
# druid                                    percona-server@5.6
# duck                                     perl-build
# duo_unix                                 pgbouncer
# dwarfutils                               pgcli
# dxpy                                     pgpool-ii
# dynare                                   php
# eccodes                                  php-code-sniffer
# efl                                      php@7.1
# elasticsearch@5.6                        phplint
# elektra                                  phpmyadmin
# elixir                                   phpunit
# elm                                      picard-tools
# elm-format                               pilosa
# emscripten                               pkcs11-helper
# erlang                                   plantuml
# erlang@19                                platformio
# erlang@20                                pmd
# ethereum                                 ponyc
# exercism                                 poppler
# exomizer                                 postgresql
# expat                                    postgresql@9.4
# exploitdb                                postgresql@9.5
# f3                                       postgresql@9.6
# faas-cli                                 pre-commit
# fabric                                   prest
# fbi-servefiles                           presto
# fd                                       prettier
# fdclone                                  primesieve
# feedgnuplot                              proselint
# fibjs                                    protobuf-c
# field3d                                  pspg
# firebase-cli                             pushpin
# flann                                    puzzles
# flatcc                                   pyenv
# flow                                     pyinvoke
# fluent-bit                               pyside
# fn                                       qemu
# folly                                    qpdf
# fonttools                                qtkeychain
# fortio                                   quicktype
# freeimage                                rabbitmq
# freetds                                  radare2
# fselect                                  rakudo-star
# futhark                                  rancher-cli
# fwknop                                   re2
# fwup                                     re2c
# gammaray                                 reattach-to-user-namespace
# gdb                                      redis
# gegl                                     rename
# geoipupdate                              restic
# geos                                     riemann-client
# get_iplayer                              ripgrep
# ghostscript                              rocksdb
# giflib                                   root
# gimme                                    roswell
# git-annex                                rsyslog
# git-archive-all                          rtv
# git-cola                                 ruby-build
# git-extras                               ruby-install
# git-lfs                                  rust
# git-quick-stats                          s-nail
# gitbucket                                s6
# gitlab-gem                               saxon
# gitlab-runner                            sbcl
# gitup                                    sbt
# gjstest                                  sceptre
# glib                                     schismtracker
# glib-networking                          scrcpy
# glslviewer                               shellharden
# gmt                                      shfmt
# gmt@4                                    shibboleth-sp
# gnatsd                                   singular
# gnome-builder                            skaffold
# gnome-latex                              skafos
# gnumeric                                 skinny
# gnupg                                    skktools
# gnupg@1.4                                sleuthkit
# go                                       smlnj
# go-bindata                               snakemake
# go-jira                                  sonarqube
# go-statik                                sourcekitten
# gobject-introspection                    sourcery
# gobuster                                 spdlog
# gocryptfs                                sphinx-doc
# godep                                    sqlmap
# goenv                                    sqoop
# goffice                                  sratoolkit
# gomplate                                 ssh-copy-id
# goreleaser                               ssh-permit-a38
# gpac                                     sshguard
# gradle                                   sshtrix
# grafana                                  sslyze
# grails                                   stanford-ner
# grakn                                    stanford-parser
# graphite2                                stern
# gromacs                                  stone-soup
# groonga                                  sundials
# groovy                                   svtplay-dl
# groovysdk                                swift
# grpc                                     swift-protobuf
# grunt-completion                         swiftformat
# gsoap                                    swiftlint
# gst-editing-services                     sysdig
# gst-plugins-bad                          tarantool
# gtk-vnc                                  tarsnap-gui
# guile                                    taskell
# gupnp                                    tbox
# gutenberg                                telegraf
# hadolint                                 teleport
# hadoop                                   termius
# haproxy                                  terraform
# harfbuzz                                 terraform_landscape
# hashcat                                  terragrunt
# hcloud                                   the_silver_searcher
# hebcal                                   tig
# heroku                                   tippecanoe
# hexgui                                   titlecase
# hh                                       tmate
# hive                                     tmux-xpanes
# hopenpgp-tools                           todolist
# htmldoc                                  tokei
# hub                                      tomcat
# hugo                                     tomcat-native
# i2p                                      tomcat@7
# icdiff                                   tomcat@8
# igv                                      tox
# imagemagick                              trafficserver
# imagemagick@6                            translate-shell
# imageoptim-cli                           travis
# influxdb                                 tty-solitaire
# ios-webkit-debug-proxy                   tup
# ipfs                                     twarc
# ipython                                  twoping
# ipython@5                                typescript
# iso-codes                                ubertooth
# jadx                                     uhd
# jboss-forge                              unixodbc
# jenkins                                  upx
# jenkins-job-builder                      urh
# jenkins-lts                              uriparser
# jfrog-cli-go                             util-linux
# jhipster                                 v8
# jlog                                     vagrant-completion
# jpeg-turbo                               vala
# json-fortran                             vault
# juju                                     vcftools
# kafka                                    vegeta
# kallisto                                 verilator
# kapacitor                                vim
# kerl                                     virtuoso
# kibana@5.6                               vrpn
# knot                                     vsts-cli
# knot-resolver                            vtk
# kontena                                  watchexec
# kops                                     webdis
# kore                                     webpack
# kotlin                                   wine
# kubectx                                  winetricks
# kubeless                                 wireguard-tools
# kubernetes-cli                           wireshark
# kubernetes-helm                          wp-cli
# ldc                                      wp-cli-completion
# lftp                                     wtf
# libatomic_ops                            wxmac
# libbi                                    xcodegen
# libdazzle                                xml-security-c
# libgit2                                  xml-tooling-c
# libgsf                                   xonsh
# libhdhomerun                             xtensor
# libical                                  yafc
# libmatio                                 yara
# libomp                                   yarn
# libpcap                                  you-get
# libphonenumber                           youtube-dl
# libpq                                    yubico-piv-tool
# libpqxx                                  zabbix
# libpst                                   zanata-client
# libqalculate                             zebra
# librealsense                             zero-install
# librtlsdr                                zsh-completions
# libsoup
# ==> Deleted Formulae
# boot2docker                ghc@8.0                    node@4
# boot2docker-completion     gnupg@2.0
# dirmngr                    gpg-agent
# ==> Downloading https://homebrew.bintray.com/bottles/portaudio-19.6.0.high_sierr
# ######################################################################## 100.0%
# ==> Pouring portaudio--19.6.0.high_sierra.bottle.tar.gz
# 🍺  /usr/local/Cellar/portaudio/19.6.0: 33 files, 452KB

# %%
# !pip install pyaudio
# Out:
# Collecting pyaudio
#   Using cached https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Running setup.py bdist_wheel for pyaudio ... error
#   Complete output from command /Users/boson/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-install-a585ddcs/pyaudio/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-wheel-d491brl0 --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   copying src/pyaudio.py -> build/lib.macosx-10.7-x86_64-3.6
#   running build_ext
#   building '_portaudio' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/src
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/boson/anaconda3/include -arch x86_64 -I/Users/boson/anaconda3/include -arch x86_64 -DMACOSX=1 -I/Users/boson/anaconda3/include/python3.6m -c src/_portaudiomodule.c -o build/temp.macosx-10.7-x86_64-3.6/src/_portaudiomodule.o
#   src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#   #include "portaudio.h"
#            ^~~~~~~~~~~~~
#   1 error generated.
#   error: command 'gcc' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#   Running setup.py install for pyaudio ... error
#     Complete output from command /Users/boson/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-install-a585ddcs/pyaudio/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-record-xiohh_av/install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     copying src/pyaudio.py -> build/lib.macosx-10.7-x86_64-3.6
#     running build_ext
#     building '_portaudio' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     creating build/temp.macosx-10.7-x86_64-3.6/src
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/boson/anaconda3/include -arch x86_64 -I/Users/boson/anaconda3/include -arch x86_64 -DMACOSX=1 -I/Users/boson/anaconda3/include/python3.6m -c src/_portaudiomodule.c -o build/temp.macosx-10.7-x86_64-3.6/src/_portaudiomodule.o
#     src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#     #include "portaudio.h"
#              ^~~~~~~~~~~~~
#     1 error generated.
#     error: command 'gcc' failed with exit status 1
#
#     ----------------------------------------
# Command "/Users/boson/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-install-a585ddcs/pyaudio/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-record-xiohh_av/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /private/var/folders/56/3141j_l176zflxjcbz_khdbm0000gn/T/pip-install-a585ddcs/pyaudio/

# %%
# !pip3 install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading https://files.pythonhosted.org/packages/56/04/5259a17a16a779426f6e2ac62796135b0d4a59cf8033a21037fd4ba5bf81/google_api_python_client-1.7.4-py3-none-any.whl (55kB)
#     100% |████████████████████████████████| 61kB 48kB/s ta 0:00:01
# Requirement already satisfied: six<2dev,>=1.6.1 in /Users/boson/anaconda3/lib/python3.6/site-packages (from google-api-python-client) (1.11.0)
# Collecting google-auth-httplib2>=0.0.3 (from google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/33/49/c814d6d438b823441552198f096fcd0377fd6c88714dbed34f1d3c8c4389/google_auth_httplib2-0.0.3-py2.py3-none-any.whl
# Collecting google-auth>=1.4.1 (from google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/58/cb/96dbb4e50e7a9d856e89cc9c8e36ab1055f9774f7d85f37e2156c1d79d9f/google_auth-1.5.1-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 53kB/s ta 0:00:01
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/e5/7d/9d5a640c4f8bf2c8b1afc015e9a9d8de32e13c9016dcc4b0ec03481fb396/uritemplate-3.0.0-py2.py3-none-any.whl
# Collecting httplib2<1dev,>=0.9.2 (from google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/fd/ce/aa4a385e3e9fd351737fd2b07edaa56e7a730448465aceda6b35086a0d9b/httplib2-0.11.3.tar.gz (215kB)
#     100% |████████████████████████████████| 225kB 52kB/s ta 0:00:01
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.4.1->google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/19/02/fa63f7ba30a0d7b925ca29d034510fc1ffde53264b71b4155022ddf3ab5d/pyasn1_modules-0.2.2-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 13kB/s ta 0:00:012
# Collecting rsa>=3.1.4 (from google-auth>=1.4.1->google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/e1/ae/baedc9cb175552e95f3395c43055a6a5e125ae4d48a1d7a924baca83e92e/rsa-3.4.2-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 10kB/s eta 0:00:01
# Collecting cachetools>=2.0.0 (from google-auth>=1.4.1->google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/0a/58/cbee863250b31d80f47401d04f34038db6766f95dea1cc909ea099c7e571/cachetools-2.1.0-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.1 (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client)
#   Downloading https://files.pythonhosted.org/packages/d1/a1/7790cc85db38daa874f6a2e6308131b9953feb1367f2ae2d1123bb93a9f5/pyasn1-0.4.4-py2.py3-none-any.whl (72kB)
#     100% |████████████████████████████████| 81kB 64kB/s ta 0:00:011
# Building wheels for collected packages: httplib2
#   Running setup.py bdist_wheel for httplib2 ... done
#   Stored in directory: /Users/boson/Library/Caches/pip/wheels/1b/9c/9e/1f6fdb21dbb1fe6a99101d697f12cb8c1fa96c1587df69adba
# Successfully built httplib2
# Installing collected packages: httplib2, pyasn1, pyasn1-modules, rsa, cachetools, google-auth, google-auth-httplib2, uritemplate, google-api-python-client
# Successfully installed cachetools-2.1.0 google-api-python-client-1.7.4 google-auth-1.5.1 google-auth-httplib2-0.0.3 httplib2-0.11.3 pyasn1-0.4.4 pyasn1-modules-0.2.2 rsa-3.4.2 uritemplate-3.0.0
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !brew install flac
# Out:
# Updating Homebrew...
# Warning: flac 1.3.2_1 is already installed and up-to-date
# To reinstall 1.3.2_1, run `brew reinstall flac`

# %%
# !brew install flac
# Out:
# Warning: flac 1.3.2_1 is already installed and up-to-date
# To reinstall 1.3.2_1, run `brew reinstall flac`

# %%
# !pip install --upgrade pip
# Out:
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/5f/25/e52d3f31441505a5f3af41213346e5b6c221c9e086a166f3703d2ddaf940/pip-18.0-py2.py3-none-any.whl
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-18.0

# %%
# !pip install pyaudio
# Out:
# Collecting pyaudio
#   Using cached https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Running setup.py bdist_wheel for pyaudio ... done
#   Stored in directory: /Users/boson/Library/Caches/pip/wheels/f4/a8/a4/292214166c2917890f85b2f72a8e5f13e1ffa527c4200dcede
# Successfully built pyaudio
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.11

# %%
import speech_recognition as sr
for index, name in enumerate(sr.Microphone.list_microphone_names()):
    print("Microphone with name \"{1}\" found for `Microphone(device_index={0})`".format(index, name))
# Out:
# Microphone with name "Built-in Microphone" found for `Microphone(device_index=0)`
# Microphone with name "Built-in Output" found for `Microphone(device_index=1)`

# %%
import speech_recognition as sr

# %%
# obtain audio from the microphone
r = sr.Recognizer()
with sr.Microphone() as source:
    print("Say something!")
    audio = r.listen(source)

# write audio to a RAW file
with open("microphone-results.raw", "wb") as f:
    f.write(audio.get_raw_data())

# write audio to a WAV file
with open("microphone-results.wav", "wb") as f:
    f.write(audio.get_wav_data())

# write audio to an AIFF file
with open("microphone-results.aiff", "wb") as f:
    f.write(audio.get_aiff_data())

# write audio to a FLAC file
with open("microphone-results.flac", "wb") as f:
    f.write(audio.get_flac_data())
# Out:
# Say something!

# %% [markdown]
# # Geeks for Geeks

# %%
#Python program for Speech Recognition
 
import speech_recognition as sr
 
#enter the name of usb microphone that you found
#using lsusb
#the following name is only used as an example
mic_name = "USB Device 0x46d:0x825: Audio (hw:1, 0)"
#Sample rate is how often values are recorded
sample_rate = 48000
#Chunk is like a buffer. It stores 2048 samples (bytes of data)
#here. 
#it is advisable to use powers of 2 such as 1024 or 2048
chunk_size = 2048
#Initialize the recognizer
r = sr.Recognizer()
 
#generate a list of all audio cards/microphones
mic_list = sr.Microphone.list_microphone_names()
 
#the following loop aims to set the device ID of the mic that
#we specifically want to use to avoid ambiguity.
device_id = 0
for i, microphone_name in enumerate(mic_list):
    if microphone_name == mic_name:
        device_id = i
 
#use the microphone as source for input. Here, we also specify 
#which device ID to specifically look for incase the microphone 
#is not working, an error will pop up saying "device_id undefined"
with sr.Microphone(device_index = device_id, sample_rate = sample_rate, 
                        chunk_size = chunk_size) as source:
    #wait for a second to let the recognizer adjust the 
    #energy threshold based on the surrounding noise level
    r.adjust_for_ambient_noise(source)
    print("Say Something")
    #listens for the user's input
    audio = r.listen(source)
         
    try:
        text = r.recognize_google(audio)
        print("you said: " + text)
     
    #error occurs when google could not understand what was said
     
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
     
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Say Something
# you said: i a m e s h a n p a n d a y @ gmail.com

# %% [markdown]
# ## Transcribe an Audio file to text

# %%
#Python 2.x program to transcribe an Audio file
import speech_recognition as sr
 
AUDIO_FILE = ("example.wav")
 
# use the audio file as the audio source
 
r = sr.Recognizer()
 
with sr.AudioFile(AUDIO_FILE) as source:
    #reads the audio file. Here we use record instead of
    #listen
    audio = r.record(source)  
 
try:
    print("The audio file contains: " + r.recognize_google(audio))
 
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
 
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-5512bdbd5750> in <module>()
#      11 r = sr.Recognizer()
#      12
# ---> 13 with sr.AudioFile(AUDIO_FILE) as source:
#      14     #reads the audio file. Here we use record instead of
#      15     #listen
#
# ~/anaconda3/lib/python3.6/site-packages/speech_recognition/__init__.py in __enter__(self)
#     201         try:
#     202             # attempt to read the file as WAV
# --> 203             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     204             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#     205         except (wave.Error, EOFError):
#
# ~/anaconda3/lib/python3.6/wave.py in open(f, mode)
#     497             mode = 'rb'
#     498     if mode in ('r', 'rb'):
# --> 499         return Wave_read(f)
#     500     elif mode in ('w', 'wb'):
#     501         return Wave_write(f)
#
# ~/anaconda3/lib/python3.6/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
#     160             self._i_opened_the_file = f
#     161         # else, assume it is an open file object already
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.wav'

# %%
s = 'i a m e s h a n @ gmail.com'
s = s.replace(" ", "")
s
# Out:
# 'iameshan@gmail.com'
